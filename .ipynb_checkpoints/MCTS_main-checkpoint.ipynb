# %%
from mcts_model import AlphaZeroNN, ReplayBuffer, MCTS_Policy, Trainer, generate_lbfs_start_states, CONFIG
from mcts_worker import run_episode_worker

# %%
lbfs_start_states = generate_lbfs_start_states(num_states=100, warmup=10000, separation=2500)
# Out:
# --- Generating 100 Warm Start States using LBFS ---
# Warming up for 10000 time units...
#   Captured 50/100 states...
#   Captured 100/100 states...
# Generation Complete.

# %%
trainer = Trainer(CONFIG, start_states=lbfs_start_states)

# 4. Run Parallel!
# num_workers=2 is safe for free Colab. 
# num_workers=4 is good for Pro.
trainer.run_training_loop_parallel(num_workers=2)
# Out:
# MCTS Policy initialized with 7 master actions.
# Trainer init: state_size=10, action_space_size=7
# MCTS Policy initialized with 7 master actions.
#
# --- PARALLEL TRAINING: 100 loops x 50 episodes ---
# Workers: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       1 trainer = Trainer(CONFIG, start_states=lbfs_start_states)
#       3 # 4. Run Parallel!
#       4 # num_workers=2 is safe for free Colab.
#       5 # num_workers=4 is good for Pro.
# ----> 6 trainer.run_training_loop_parallel(num_workers=2)
#
# File ~/Desktop/research/mcts_model.py:661, in Trainer.run_training_loop_parallel(self, num_workers)
#     658 print(f"\n--- PARALLEL TRAINING: {self.config['num_train_loops']} loops x {self.config['episodes_per_loop']} episodes ---")
#     659 print(f"Workers: {num_workers}")
# --> 661 ctx = mp.get_context('spawn') # Safer for Torch
# ...
